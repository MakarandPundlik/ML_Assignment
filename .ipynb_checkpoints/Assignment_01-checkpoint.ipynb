# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Boston hdata.csv')
df.head()
# Out:
#    0.00632   18  2.31    0  0.538  6.575  65.2    4.09  1    296  15.3  \
# 0  0.02731  0.0  7.07  0.0  0.469  6.421  78.9  4.9671  2  242.0  17.8
# 1  0.02729  0.0  7.07  0.0  0.469  7.185  61.1  4.9671  2  242.0  17.8
# 2  0.03237  0.0  2.18  0.0  0.458  6.998  45.8  6.0622  3  222.0  18.7
# 3  0.06905  0.0  2.18  0.0  0.458  7.147  54.2  6.0622  3  222.0  18.7
# 4  0.02985  0.0  2.18  0.0  0.458  6.430  58.7  6.0622  3  222.0  18.7
#
#     396.9  4.98    24
# 0  396.90  9.14  21.6
# 1  392.83  4.03  34.7
# 2  394.63  2.94  33.4
# 3  396.90  5.33  36.2
# 4  394.12  5.21  28.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0.00632  505 non-null    float64
#  1   18       505 non-null    float64
#  2   2.31     505 non-null    float64
#  3   0        505 non-null    float64
#  4   0.538    505 non-null    float64
#  5   6.575    505 non-null    float64
#  6   65.2     505 non-null    float64
#  7   4.09     505 non-null    float64
#  8   1        505 non-null    int64
#  9   296      505 non-null    float64
#  10  15.3     505 non-null    float64
#  11  396.9    505 non-null    float64
#  12  4.98     505 non-null    float64
#  13  24       451 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.4 KB

# %%
len(df.columns)
# Out:
# 14

# %%
df.columns  = ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat','medv']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     505 non-null    float64
#  1   zn       505 non-null    float64
#  2   indus    505 non-null    float64
#  3   chas     505 non-null    float64
#  4   nox      505 non-null    float64
#  5   rm       505 non-null    float64
#  6   age      505 non-null    float64
#  7   dis      505 non-null    float64
#  8   rad      505 non-null    int64
#  9   tax      505 non-null    float64
#  10  ptratio  505 non-null    float64
#  11  b        505 non-null    float64
#  12  lstat    505 non-null    float64
#  13  medv     451 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.4 KB

# %%
df
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 1    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 2    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 3    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# 4    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 500  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 501  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 502  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 503  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 504  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      ptratio       b  lstat  medv
# 0       17.8  396.90   9.14  21.6
# 1       17.8  392.83   4.03  34.7
# ...

# %% [markdown]
# ## conclusions on dataset
# ### only 451 houses have non null selling price, i.e effective size of dataset is 451
# ### all values are either in float64 or int32 format, no need to convert

# %% [markdown]
# ## backup dataset

# %%
backup = df.copy()
backup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     505 non-null    float64
#  1   zn       505 non-null    float64
#  2   indus    505 non-null    float64
#  3   chas     505 non-null    float64
#  4   nox      505 non-null    float64
#  5   rm       505 non-null    float64
#  6   age      505 non-null    float64
#  7   dis      505 non-null    float64
#  8   rad      505 non-null    int64
#  9   tax      505 non-null    float64
#  10  ptratio  505 non-null    float64
#  11  b        505 non-null    float64
#  12  lstat    505 non-null    float64
#  13  medv     451 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.4 KB

# %% [markdown]
# ## cleaning the dataset

# %%
df[df['medv'].notnull()]
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 1    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 2    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 3    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# 4    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 500  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 501  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 502  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 503  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 504  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      ptratio       b  lstat  medv
# 0       17.8  396.90   9.14  21.6
# 1       17.8  392.83   4.03  34.7
# ...

# %%
df = df[df['medv'].notnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 451 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     451 non-null    float64
#  1   zn       451 non-null    float64
#  2   indus    451 non-null    float64
#  3   chas     451 non-null    float64
#  4   nox      451 non-null    float64
#  5   rm       451 non-null    float64
#  6   age      451 non-null    float64
#  7   dis      451 non-null    float64
#  8   rad      451 non-null    int64
#  9   tax      451 non-null    float64
#  10  ptratio  451 non-null    float64
#  11  b        451 non-null    float64
#  12  lstat    451 non-null    float64
#  13  medv     451 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 52.9 KB

# %% [markdown]
# ## saving cleaned data to new csv file

# %%
df.reset_index(drop=True)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 1    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 2    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 3    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# 4    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 446  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 447  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 448  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 449  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 450  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      ptratio       b  lstat  medv
# 0       17.8  396.90   9.14  21.6
# 1       17.8  392.83   4.03  34.7
# ...

# %%
df.to_csv('Cleaned House Prices.csv')

# %%
df['rad'].unique()
# Out:
# array([ 2,  3,  5,  4,  8,  6,  1,  7, 24], dtype=int64)

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x='rad',y='crim',data=df)
# Out:
# <AxesSubplot:xlabel='rad', ylabel='crim'>

# %% [markdown]
# ## relationship between crime rate and price

# %%
plt.figure(figsize=(16,10))
sns.relplot(x='crim',y='medv',data=df,height=7,aspect=1.5)

# %% [markdown]
# ## relationship between crime rate and tax

# %%
plt.figure(figsize=(16,10))
sns.relplot(x='tax',y='crim',data=df,height=7,aspect=1.5)

# %%
plt.figure(figsize=(16,10))
sns.distplot(x = df['medv'])
# Out:
# C:\Users\mmp23\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.pairplot(df)

# %%
# training data segregation 
X = df[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat']]
y = df[['medv']]
X
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242.0
# 1    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242.0
# 2    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222.0
# 3    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222.0
# 4    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 500  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273.0
# 501  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273.0
# 502  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273.0
# 503  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273.0
# 504  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050    1  273.0
#
#      ptratio       b  lstat
# 0       17.8  396.90   9.14
# 1       17.8  392.83   4.03
# ...

# %%
y
# Out:
#      medv
# 0    21.6
# 1    34.7
# 2    33.4
# 3    36.2
# 4    28.7
# ..    ...
# 500  22.4
# 501  20.6
# 502  23.9
# 503  22.0
# 504  11.9
#
# [451 rows x 1 columns]

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15)

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    model=LinearRegression()
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 188

# %%
scores[np.argmax(scores)]
# Out:
# 0.8949716712193705

# %%
model.predict(pd.DataFrame([[0.06905,0,2.18,0,0.458,7.147,54.2,6.0622,3,222,18.7,396.9,5.33]],columns= ['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat']))
# Out:
# array([[28.78358932]])

# %% [markdown]
# ## linear regression using two features

# %%
X = df[['rm']] # number of rooms 
y = df[['medv']] #selling price

# %%
X
# Out:
#         rm
# 0    6.421
# 1    7.185
# 2    6.998
# 3    7.147
# 4    6.430
# ..     ...
# 500  6.593
# 501  6.120
# 502  6.976
# 503  6.794
# 504  6.030
#
# [451 rows x 1 columns]

# %%
y
# Out:
#      medv
# 0    21.6
# 1    34.7
# 2    33.4
# 3    36.2
# 4    28.7
# ..    ...
# 500  22.4
# 501  20.6
# 502  23.9
# 503  22.0
# 504  11.9
#
# [451 rows x 1 columns]

# %%
model = LinearRegression()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6651948054676948
