# %%
import numpy as np
import math

# %%
x1,x2=0.05,0.10
w1,w5=0.15,0.40
w2,w6=0.20,0.45
w3,w7=0.25,0.50
w4,w8=0.30,0.55

# %%
t1,t2=0.01,0.99

# %%
b1,b2=0.35,0.60

# %%
h1=1/(1+1/math.exp(x1*w1+x2*w2+b1))
h2=1/(1+1/math.exp(x1*w3+x2*w4+b1))
print(h1,h2)
# Out:
# 0.5932699921071872 0.596884378259767

# %%
y1=1/(1+1/math.exp(h1*w5+h2*w6+b2))
y2=1/(1+1/math.exp(h1*w7+h2*w8+b2))
print(y1,y2)
# Out:
# 0.7513650695523157 0.7729284653214625

# %%
Etotal=1/2*(t1-y1)**2+1/2*(t2-y2)**2
print(Etotal)
# Out:
# 0.2983711087600027
